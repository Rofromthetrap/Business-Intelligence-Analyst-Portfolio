# %% [markdown]
# # Bitcoin Daily Price tracker
# ## Gets Bitcoin prices for the past 30 days
# ### Updates weekly, on Monday

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from twelvedata import TDClient
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import mplfinance as mpf

# %%
load_dotenv()  # loads .env locally; no-op in GitHub Actions

api_key = os.getenv("API_KEY")

# %%
#print(notebook_dir)
#print(api_key)

# %%
td = TDClient(apikey=api_key)
ts = td.time_series(
    symbol="BTC/USD",
    exchange="Binance",
    interval="1day",
    outputsize=30,
    timezone="Africa/Dar_es_Salaam",
)

# %%
# Returns pandas.DataFrame
df = ts.as_pandas()
df
# Out:
#                 open      high       low     close
# datetime
# 2026-08-31  77682.00  78802.00  77392.00  78522.84
# 2026-08-30  78230.00  79400.00  77000.00  77682.00
# 2026-08-29  77845.88  78330.00  77382.37  78230.00
# 2026-08-28  80249.59  81478.87  76888.00  77845.87
# 2026-08-27  79023.75  80848.74  78546.13  80249.58
# 2026-08-26  78539.13  79251.60  77632.58  79023.75
# 2026-08-25  78992.76  81272.62  77851.00  78539.14
# 2026-08-24  77734.00  80000.00  76670.01  78992.75
# 2026-08-23  77074.94  78052.85  75545.67  77734.00
# 2026-08-22  78338.03  78828.15  76500.00  77074.93
# 2026-08-21  73027.02  79500.00  73027.02  78338.03
# 2026-08-20  69334.78  73400.00  68902.22  73025.15
# 2026-08-19  64725.42  70000.00  64166.00  69334.79
# 2026-08-18  64532.11  65058.81  64027.85  64725.42
# 2026-08-17  62900.00  64610.01  62751.10  64532.10
# 2026-08-16  63086.01  63390.00  62716.00  62900.00
# 2026-08-15  63043.56  63187.98  62920.00  63086.01
# 2026-08-14  63490.86  63617.45  62535.24  63043.56
# 2026-08-13  63479.99  64010.00  62802.27  63490.86
# 2026-08-12  63600.01  64500.00  63310.34  63479.99
# 2026-08-11  63970.01  64515.43  63238.00  63600.00
# 2026-08-10  64901.59  65391.14  63806.27  63970.01
# 2026-08-09  64962.60  65474.46  64730.08  64901.59
# 2026-08-08  64923.20  65192.54  64784.19  64962.60
# 2026-08-07  64323.61  65390.99  64166.00  64923.19
# 2026-08-06  64665.24  64999.00  64172.00  64323.61
# 2026-08-05  64106.55  65025.22  63880.00  64665.23
# 2026-08-04  63520.00  64549.16  63322.01  64106.56
# 2026-08-03  63570.01  64080.00  62300.00  63520.00
# 2026-08-02  62823.65  63796.33  62806.58  63570.00

# %%
#Create a line chart
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['close'], linewidth=2, color='#1f77b4', label='Close Price')

# Add comma formatting to y-axis
ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: f'{x:,.0f}'))

# Customize the chart
plt.title('BTC/USD Price - Last 30 Days', fontsize=14, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# Display the chart
plt.show()
