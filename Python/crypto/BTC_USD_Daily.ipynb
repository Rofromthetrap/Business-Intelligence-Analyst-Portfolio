# %% [markdown]
# # Bitcoin Daily Price tracker
# ## Gets Bitcoin prices for the past 30 days

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from twelvedata import TDClient
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import mplfinance as mpf

# %%
load_dotenv()  # loads .env locally; no-op in GitHub Actions

api_key = os.getenv("API_KEY")

# %%
#print(notebook_dir)
#print(api_key)

# %%
td = TDClient(apikey=api_key)
ts = td.time_series(
    symbol="BTC/USD",
    exchange="Binance",
    interval="1day",
    outputsize=30,
    timezone="Africa/Dar_es_Salaam",
)

# %%
# Returns pandas.DataFrame
df = ts.as_pandas()
df
# Out:
#                 open      high       low     close
# datetime
# 2026-04-03  66901.99  67370.42  66282.00  66901.30
# 2026-04-02  68113.92  68653.38  65712.12  66901.99
# 2026-04-01  68284.49  69310.00  67578.75  68113.92
# 2026-03-31  66797.38  68589.49  65998.05  68284.48
# 2026-03-30  66010.93  68169.65  65800.59  66797.37
# 2026-03-29  66377.04  67130.50  65000.00  66010.93
# 2026-03-28  66407.28  67288.94  65932.09  66377.03
# 2026-03-27  68820.31  69179.05  65548.25  66407.28
# 2026-03-26  71336.53  71436.82  68153.00  68820.31
# 2026-03-25  70556.74  72026.09  70408.00  71336.53
# 2026-03-24  70906.45  71400.00  68923.07  70556.74
# 2026-03-23  67859.00  71817.09  67445.18  70906.45
# 2026-03-22  68918.12  69588.79  67360.66  67859.00
# 2026-03-21  70510.73  71100.94  68571.42  68918.12
# 2026-03-20  69930.01  71367.00  69388.00  70510.73
# 2026-03-19  71246.55  71613.79  68793.35  69930.00
# 2026-03-18  73909.37  74672.34  70500.00  71246.54
# 2026-03-17  74884.67  76000.00  73399.19  73909.36
# 2026-03-16  72815.25  74909.08  72270.41  74884.67
# 2026-03-15  71211.95  73199.00  70858.82  72815.24
# 2026-03-14  70930.01  71307.92  70317.00  71211.95
# 2026-03-13  70541.34  73913.74  70386.01  70930.00
# 2026-03-12  70191.86  70800.00  69205.91  70541.34
# 2026-03-11  69948.64  71321.00  68977.91  70191.86
# 2026-03-10  68432.16  71777.00  68391.41  69948.63
# 2026-03-09  65971.20  69516.65  65821.97  68432.16
# 2026-03-08  67262.91  68200.00  65618.49  65971.20
# 2026-03-07  68114.02  68551.04  66915.26  67262.91
# 2026-03-06  70891.02  71419.98  67744.78  68114.02
# 2026-03-05  72666.77  73558.15  70645.47  70890.72

# %%
#Create a line chart
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['close'], linewidth=2, color='#1f77b4', label='Close Price')

# Add comma formatting to y-axis
ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: f'{x:,.0f}'))

# Customize the chart
plt.title('BTC/USD Price - Last 30 Days', fontsize=14, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# Display the chart
plt.show()
