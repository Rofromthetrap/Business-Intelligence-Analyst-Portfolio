# %% [markdown]
# # Bitcoin Daily Price tracker
# ## Gets Bitcoin prices for the past 30 days
# ### Updates weekly, on Monday

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from twelvedata import TDClient
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import mplfinance as mpf

# %%
load_dotenv()  # loads .env locally; no-op in GitHub Actions

api_key = os.getenv("API_KEY")

# %%
#print(notebook_dir)
#print(api_key)

# %%
td = TDClient(apikey=api_key)
ts = td.time_series(
    symbol="BTC/USD",
    exchange="Binance",
    interval="1day",
    outputsize=30,
    timezone="Africa/Dar_es_Salaam",
)

# %%
# Returns pandas.DataFrame
df = ts.as_pandas()
df
# Out:
#                 open      high       low     close
# datetime
# 2026-06-08  63332.01  63863.06  62408.00  63218.68
# 2026-06-07  60884.62  64234.68  60746.00  63332.01
# 2026-06-06  61056.47  61530.05  59500.00  60884.62
# 2026-06-05  63885.99  63978.00  59130.91  61056.47
# 2026-06-04  64142.75  64764.32  61383.56  63885.99
# 2026-06-03  66760.84  67516.00  64092.49  64142.75
# 2026-06-02  71408.90  71408.90  66193.00  66760.83
# 2026-06-01  73674.39  74092.00  70686.68  71408.90
# 2026-05-31  73884.38  74275.66  73400.00  73674.39
# 2026-05-30  73460.78  74143.76  73216.00  73884.38
# 2026-05-29  73617.52  74514.10  72512.49  73460.78
# 2026-05-28  74449.31  74590.77  72582.82  73617.51
# 2026-05-27  75930.01  76174.15  74243.99  74449.30
# 2026-05-26  77322.01  78080.00  75677.97  75930.01
# 2026-05-25  77064.96  77905.52  76914.25  77322.01
# 2026-05-24  76752.00  77543.15  76108.00  77064.96
# 2026-05-23  75539.50  77404.18  74289.60  76752.01
# 2026-05-22  77615.52  77900.00  75359.18  75539.50
# 2026-05-21  77552.24  78200.00  76719.47  77615.52
# 2026-05-20  76834.36  77853.04  76516.74  77552.23
# 2026-05-19  77001.88  77414.62  76144.71  76834.36
# 2026-05-18  77457.67  77800.00  76051.00  77001.87
# 2026-05-17  78148.05  78599.99  76735.16  77457.67
# 2026-05-16  79113.20  79227.77  77640.00  78148.05
# 2026-05-15  81090.00  81664.45  78659.00  79113.21
# 2026-05-14  79313.61  82048.13  78922.00  81089.99
# 2026-05-13  80504.47  81324.64  78754.65  79313.61
# 2026-05-12  81745.66  81788.00  79843.59  80504.47
# 2026-05-11  82210.07  82380.00  80462.97  81745.65
# 2026-05-10  80678.41  82479.32  80279.77  82210.07

# %%
#Create a line chart
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['close'], linewidth=2, color='#1f77b4', label='Close Price')

# Add comma formatting to y-axis
ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: f'{x:,.0f}'))

# Customize the chart
plt.title('BTC/USD Price - Last 30 Days', fontsize=14, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# Display the chart
plt.show()
