# %% [markdown]
# # Bitcoin Daily Price tracker
# ## Gets Bitcoin prices for the past 30 days
# ### Updates weekly, on Monday

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from twelvedata import TDClient
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import mplfinance as mpf

# %%
load_dotenv()  # loads .env locally; no-op in GitHub Actions

api_key = os.getenv("API_KEY")

# %%
#print(notebook_dir)
#print(api_key)

# %%
td = TDClient(apikey=api_key)
ts = td.time_series(
    symbol="BTC/USD",
    exchange="Binance",
    interval="1day",
    outputsize=30,
    timezone="Africa/Dar_es_Salaam",
)

# %%
# Returns pandas.DataFrame
df = ts.as_pandas()
df
# Out:
#                 open      high       low     close
# datetime
# 2026-07-20  64722.55  65107.99  63765.83  64072.02
# 2026-07-19  64834.21  64967.25  64280.00  64722.54
# 2026-07-18  63931.67  64865.00  63886.65  64834.22
# 2026-07-17  63830.20  64387.99  62537.56  63931.67
# 2026-07-16  64756.28  64997.52  63748.74  63830.20
# 2026-07-15  65043.99  65600.00  64485.00  64756.28
# 2026-07-14  62334.52  65100.00  62272.20  65043.98
# 2026-07-13  63780.00  64425.00  61824.97  62334.52
# 2026-07-12  63819.01  64290.11  63640.83  63780.00
# 2026-07-11  64161.72  64504.11  63819.00  63819.00
# 2026-07-10  63230.01  64692.83  62926.01  64161.72
# 2026-07-09  62290.01  63500.00  61705.29  63230.00
# 2026-07-08  63364.00  63761.99  61544.56  62290.00
# 2026-07-07  64042.93  64314.00  62671.39  63363.99
# 2026-07-06  63650.01  64700.00  61306.84  64042.02
# 2026-07-05  63144.01  63999.00  62436.59  63650.00
# 2026-07-04  62583.26  63461.99  62328.24  63144.01
# 2026-07-03  61560.00  62979.86  61248.86  62583.26
# 2026-07-02  60024.00  62200.00  59588.00  61560.00
# 2026-07-01  58624.71  61334.00  57800.19  60024.00
# 2026-06-30  60260.20  60276.54  58201.00  58624.71
# 2026-06-29  59577.01  60780.57  58900.01  60260.21
# 2026-06-28  60029.01  60545.01  58905.00  59577.01
# 2026-06-27  60097.27  60941.17  59855.16  60029.00
# 2026-06-26  59794.64  60759.99  58337.00  60097.27
# 2026-06-25  61078.00  61962.40  58115.01  59794.00
# 2026-06-24  62734.57  63239.06  59102.70  61077.99
# 2026-06-23  64020.01  64275.38  61938.00  62734.57
# 2026-06-22  63312.00  65622.83  63312.00  64020.01
# 2026-06-21  64298.01  64588.00  63270.00  63311.99

# %%
#Create a line chart
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['close'], linewidth=2, color='#1f77b4', label='Close Price')

# Add comma formatting to y-axis
ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: f'{x:,.0f}'))

# Customize the chart
plt.title('BTC/USD Price - Last 30 Days', fontsize=14, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# Display the chart
plt.show()
