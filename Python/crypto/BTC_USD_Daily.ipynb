# %% [markdown]
# # Bitcoin Daily Price tracker
# ## Gets Bitcoin prices for the past 30 days
# ### Updates weekly, on Monday

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from twelvedata import TDClient
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import mplfinance as mpf

# %%
load_dotenv()  # loads .env locally; no-op in GitHub Actions

api_key = os.getenv("API_KEY")

# %%
#print(notebook_dir)
#print(api_key)

# %%
td = TDClient(apikey=api_key)
ts = td.time_series(
    symbol="BTC/USD",
    exchange="Binance",
    interval="1day",
    outputsize=30,
    timezone="Africa/Dar_es_Salaam",
)

# %%
# Returns pandas.DataFrame
df = ts.as_pandas()
df
# Out:
#                 open      high       low     close
# datetime
# 2026-06-29  59577.01  60346.27  58900.01  60099.70
# 2026-06-28  60029.01  60545.01  58905.00  59577.01
# 2026-06-27  60097.27  60941.17  59855.16  60029.00
# 2026-06-26  59794.64  60759.99  58337.00  60097.27
# 2026-06-25  61078.00  61962.40  58115.01  59794.00
# 2026-06-24  62734.57  63239.06  59102.70  61077.99
# 2026-06-23  64020.01  64275.38  61938.00  62734.57
# 2026-06-22  63312.00  65622.83  63312.00  64020.01
# 2026-06-21  64298.01  64588.00  63270.00  63311.99
# 2026-06-20  63543.90  64388.00  63184.21  64298.01
# 2026-06-19  62958.01  63666.00  62316.44  63543.91
# 2026-06-18  64509.40  64806.00  62272.07  62958.01
# 2026-06-17  65675.02  66445.93  63915.77  64509.40
# 2026-06-16  66328.74  66992.00  65360.92  65675.01
# 2026-06-15  65746.45  67292.15  65354.00  66328.74
# 2026-06-14  64458.01  65800.00  63678.83  65746.45
# 2026-06-13  63580.00  64762.77  63418.66  64458.01
# 2026-06-12  63626.00  64394.44  62829.81  63580.01
# 2026-06-11  61510.99  63933.02  61510.99  63625.99
# 2026-06-10  61730.00  62857.99  60755.00  61510.99
# 2026-06-09  63086.00  63526.01  60780.00  61730.00
# 2026-06-08  63332.01  64200.00  62408.00  63085.99
# 2026-06-07  60884.62  64234.68  60746.00  63332.01
# 2026-06-06  61056.47  61530.05  59500.00  60884.62
# 2026-06-05  63885.99  63978.00  59130.91  61056.47
# 2026-06-04  64142.75  64764.32  61383.56  63885.99
# 2026-06-03  66760.84  67516.00  64092.49  64142.75
# 2026-06-02  71408.90  71408.90  66193.00  66760.83
# 2026-06-01  73674.39  74092.00  70686.68  71408.90
# 2026-05-31  73884.38  74275.66  73400.00  73674.39

# %%
#Create a line chart
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['close'], linewidth=2, color='#1f77b4', label='Close Price')

# Add comma formatting to y-axis
ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: f'{x:,.0f}'))

# Customize the chart
plt.title('BTC/USD Price - Last 30 Days', fontsize=14, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# Display the chart
plt.show()
